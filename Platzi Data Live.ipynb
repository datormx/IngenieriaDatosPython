# %% [markdown]
# ## Tipos de datos

# %%
import sys 
sys.path #import sources
# Out:
# ['/mnt/d/Git_Repositories/IngenieriaDatosPython',
#  '/tmp/846a8566-66c9-4ba7-9f47-991fffed5321',
#  '/home/migueltorresio/.vscode-server/extensions/ms-python.python-2020.8.106424/pythonFiles',
#  '/home/migueltorresio/.vscode-server/extensions/ms-python.python-2020.8.106424/pythonFiles/lib/python',
#  '/home/migueltorresio/anaconda3/envs/platzi_datos/lib/python38.zip',
#  '/home/migueltorresio/anaconda3/envs/platzi_datos/lib/python3.8',
#  '/home/migueltorresio/anaconda3/envs/platzi_datos/lib/python3.8/lib-dynload',
#  '',
#  '/home/migueltorresio/anaconda3/envs/platzi_datos/lib/python3.8/site-packages',
#  '/home/migueltorresio/anaconda3/envs/platzi_datos/lib/python3.8/site-packages/IPython/extensions',
#  '/home/migueltorresio/.ipython']

# %%
sys.executable #Python version origin
# Out:
# '/home/migueltorresio/anaconda3/envs/platzi_datos/bin/python'

# %% [markdown]
# ### Primitivos

# %%
from datetime import datetime

integer_type = 42
float_type = 3.14159
bool_type = False
hex_type = 0xff
oct_type = 0o23
today = datetime.now()
str_type = 'David'

# %% [markdown]
# ### Estructurados

# %%
from IPython.display import Image

Image('mysql_table_example.png')

# %% [markdown]
# ### Semi estructurados

# %%
Image('html_markup_example.png')

# %% [markdown]
# ### No estructurados

# %% [markdown]
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Solicitudes a la web

# %%
import requests

response = requests.get('https://platzi.com/datos/')

# response? #En Jupyter el signo ? sirve de ayuda para conocer información del objeto.
# response?? #En Jupyter el doble signo ?? muestra el código fuente del objeto y su documentación.
print(dir(response)) #Muestra los métodos que se pueden utilizar con el objeto.
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.headers)
print('\n')
print(response.headers['Date'])
print(response.headers['Content-Type'])
print(response.headers['Transfer-Encoding'])
print(response.headers['Server'])
# Out:
# {'Date': 'Sun, 23 Aug 2020 14:06:22 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d05ad9df504708a7203fcbcfd5fe6e5251598191581; expires=Tue, 22-Sep-20 14:06:21 GMT; path=/; domain=.platzi.com; HttpOnly; SameSite=Lax, tracking_token=e41d3052-7453-4ac3-b522-51bfab6fe150; expires=Mon, 23 Aug 2021 14:06:22 GMT; Max-Age=31536000; Path=/, entry_path="/datos/"; expires=Sun, 23 Aug 2020 14:56:22 GMT; Max-Age=3000; Path=/, csrftoken=LEuAQsXRSaD21rBv3znusvMamBEUfeqffPlvKs1ZQEGEXKwKmJjvAMLp2usO7CKy; expires=Sun, 22 Aug 2021 14:06:22 GMT; Max-Age=31449600; Path=/; SameSite=Lax, s=i2ji71vbfi1wgd8e91t6rt29vd3h9em9; Domain=.platzi.com; expires=Sun, 23 Aug 2020 15:06:22 GMT; HttpOnly; Max-Age=3600; Path=/; Secure', 'Vary': 'Accept-Encoding, Accept-Language, Cookie, Origin', 'Content-Language': 'es-co', 'X-Frame-Options': 'SAMEORIGIN', 'Strict-Transport-Security': 'max-age=86400; includeSubDomains', 'X-Content-Type
# ...

# %%
print(response.text)
# Out:
# ps://static.platzi.com/media/flags/PM.png"}, {"id": 186, "name": "Saint Vincent and the Grenadines", "code": "+1-784", "flag": "https://static.platzi.com/media/flags/VC.png"}, {"id": 187, "name": "Samoa", "code": "+685", "flag": "https://static.platzi.com/media/flags/WS.png"}, {"id": 188, "name": "San Marino", "code": "+378", "flag": "https://static.platzi.com/media/flags/SM.png"}, {"id": 189, "name": "Sao Tome and Principe", "code": "+239", "flag": "https://static.platzi.com/media/flags/ST.png"}, {"id": 190, "name": "Saudi Arabia", "code": "+966", "flag": "https://static.platzi.com/media/flags/SA.png"}, {"id": 191, "name": "Senegal", "code": "+221", "flag": "https://static.platzi.com/media/flags/SN.png"}, {"id": 192, "name": "Serbia", "code": "+381", "flag": "https://static.platzi.com/media/flags/RS.png"}, {"id": 193, "name": "Seychelles", "code": "+248", "flag": "https://static.platzi.com/media/flags/SC.png"}, {"id": 194, "name": "Sierra Leone", "code": "+232", "flag": "https://sta
# ...

# %% [markdown]
# ## Extracción de información del HTML

# %%
import bs4

soup = bs4.BeautifulSoup(response.text, 'html.parser')

print(soup.title.text)
print(soup.select('meta[name=description]')) #Selector etiquetas
print(soup.select('meta[name=description]')[0]['content'])

courses_links = soup.select('.RoutesList-item')
print(courses_links)
courses = [course['href'] for course in courses_links]

for course in courses:
    print(course)

for course in courses:
    course = 'https://platzi.com' + course
    print(course)
# Out:
# Escuela de Data Science
# [<meta content="" name="description"/>]
#
# ...

# %% [markdown]
# ## Primera vista al dataset de noticias

# %% [markdown]
# ## Series

# %%
import pandas as pd

series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})
                
series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# ## DataFrames

# %%
frame_test = pd.DataFrame({1999: [74, 39, 39],
                           2000: [34, 32, 32],
                           2001: [23, 39, 23]})

frame_test
# frame_test[1999][0]
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    39    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[74, 39, 39], 
                            [34, 32, 32],
                            [23, 39, 23]], columns=[1999, 2000, 2001])

frame_test2
# Out:
#    1999  2000  2001
# 0    74    39    39
# 1    34    32    32
# 2    23    39    23

# %%
frame_test3 = pd.DataFrame([[74, 39, 39], 
                            [34, 32, 32],
                            [23, 39, 23]], 
                            columns=[1999, 2000, 2001], 
                            index = ['Sales', 'Investment', 'Profit'])

frame_test3
# Out:
#             1999  2000  2001
# Sales         74    39    39
# Investment    34    32    32
# Profit        23    39    23

# %% [markdown]
# ## Read data

# %%
import pandas as pd

pd.options.display.max_rows = 10

filename = 'eluniversal_2020_08_29_articles2.csv'

el_universal = pd.read_csv(f'web_scrapper_curso_data_eng/{filename}')
el_universal.dropna(how='all', axis='columns', inplace=True) #Drop columnas completamente vacías

type(el_universal)
el_universal
# Out:
#                                                  body  \
# 0   \nLa intención de Lionel Messi era presentarse...
# 1   \n\nUn ejército de hombres y mujeres —la mayor...
# 2   \nAsí como "Capulina" o "El Chavo del Ocho", M...
# 3   \nElementos de la Unidad de Antisecuestro y Ex...
# 4   \nRelajada y en bikini aparece Aislinn Derbez ...
# ..                                                ...
# 40  Lorem ipsum dolor sit amet, consectetur adipis...
# 41  Nam lectus turpis, semper ac dui vel, ultricie...
# 42  Cras ut nisi enim. Integer porta congue vulput...
# 43  Cras ut nisi enim. Integer porta congue vulput...
# 44  Nam lectus turpis, semper ac dui vel, ultricie...
#
#                                                 title  \
# 0   Messi no se presentará a hacer exámenes con el...
# 1   Crece pepena durante la pandemia; van adultos ...
# 2   Las aventuras de Manuel "El Loco" Valdés divir...
# 3   Liberan a la hermana de Enner Valencia tras su...
# ...

# %% [markdown]
# ## Index and selection

# %%
# dictionary like

el_universal['title']
# Out:
# 0     Messi no se presentará a hacer exámenes con el...
# 1     Crece pepena durante la pandemia; van adultos ...
# 2     Las aventuras de Manuel "El Loco" Valdés divir...
# 3     Liberan a la hermana de Enner Valencia tras su...
# 4         Aislinn Derbez provoca envidias por su figura
#                             ...
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# Name: title, Length: 45, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                                                 title  \
# 0   Messi no se presentará a hacer exámenes con el...
# 1   Crece pepena durante la pandemia; van adultos ...
# 2   Las aventuras de Manuel "El Loco" Valdés divir...
# 3   Liberan a la hermana de Enner Valencia tras su...
# 4       Aislinn Derbez provoca envidias por su figura
# ..                                                ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
#
#                                                   url
# 0   https://www.eluniversal.com.mx/universal-depor...
# 1   https://www.eluniversal.com.mx/nacion/crece-pe...
# 2   https://www.eluniversal.com.mx/espectaculos/la...
# 3   https://www.eluniversal.com.mx/universal-depor...
# ...

# %%
# Numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \nSi eres uno de los 72.6 millones de gamers q...
# 11  \nEl grupo parlamentario del PRI en la Cámara ...
# 12  \nDe cara a su Segundo Informe de Gobierno, el...
# 13  \nLa politóloga, Denise Dresser, publicó un vi...
# 14  \nLa muerte a los 43 años de Chadwick Boseman ...
#
#                                                 title  \
# 10  ¿Por qué se ha catapultado el número de gamers...
# 11  “No nos mueven ambiciones enfermizas”: diputad...
# 12  “Empresarios, sí; traficantes de influencias, ...
# 13  Promete Denise Dresser “perrear” por una buena...
# 14  Chadwick Boseman rodó una última aparición com...
#
#                                                   url
# 10  https://www.eluniversal.com.mx/cartera/por-que...
# 11  https://www.eluniversal.com.mx/nacion/no-nos-m...
# 12  https://www.eluniversal.com.mx/nacion/empresar...
# 13  https://www.eluniversal.com.mx/nacion/promete-...
# ...

# %%
el_universal.iloc[10]['title']
# Out:
# '¿Por qué se ha catapultado el número de gamers en México? '

# %%
el_universal.iloc[:5, 0] #No utilizable, no es legible.
# Out:
# 0    \nLa intención de Lionel Messi era presentarse...
# 1    \n\nUn ejército de hombres y mujeres —la mayor...
# 2    \nAsí como "Capulina" o "El Chavo del Ocho", M...
# 3    \nElementos de la Unidad de Antisecuestro y Ex...
# 4    \nRelajada y en bikini aparece Aislinn Derbez ...
# Name: body, dtype: object

# %%
# Label bassed

el_universal.loc[:6, 'title':'url']
# Out:
#                                                title  \
# 0  Messi no se presentará a hacer exámenes con el...
# 1  Crece pepena durante la pandemia; van adultos ...
# 2  Las aventuras de Manuel "El Loco" Valdés divir...
# 3  Liberan a la hermana de Enner Valencia tras su...
# 4      Aislinn Derbez provoca envidias por su figura
# 5  Detienen a seis elementos de la Marina por pre...
# 6  Paty Navidad dice que la vacuna contra el coro...
#
#                                                  url
# 0  https://www.eluniversal.com.mx/universal-depor...
# 1  https://www.eluniversal.com.mx/nacion/crece-pe...
# 2  https://www.eluniversal.com.mx/espectaculos/la...
# 3  https://www.eluniversal.com.mx/universal-depor...
# 4  https://www.eluniversal.com.mx/espectaculos/ai...
# 5  https://www.eluniversal.com.mx/nacion/semar-de...
# 6  https://www.eluniversal.com.mx/espectaculos/pa...

# %% [markdown]
# ## Data Wrangling

# %%
# 1. Añadir newspaper_uid al DataFrame

el_universal['newspaper_uid'] = 'el_universal'

el_universal
# Out:
#                                                  body  \
# 0   \nLa intención de Lionel Messi era presentarse...
# 1   \n\nUn ejército de hombres y mujeres —la mayor...
# 2   \nAsí como "Capulina" o "El Chavo del Ocho", M...
# 3   \nElementos de la Unidad de Antisecuestro y Ex...
# 4   \nRelajada y en bikini aparece Aislinn Derbez ...
# ..                                                ...
# 40  Lorem ipsum dolor sit amet, consectetur adipis...
# 41  Nam lectus turpis, semper ac dui vel, ultricie...
# 42  Cras ut nisi enim. Integer porta congue vulput...
# 43  Cras ut nisi enim. Integer porta congue vulput...
# 44  Nam lectus turpis, semper ac dui vel, ultricie...
#
#                                                 title  \
# 0   Messi no se presentará a hacer exámenes con el...
# 1   Crece pepena durante la pandemia; van adultos ...
# 2   Las aventuras de Manuel "El Loco" Valdés divir...
# 3   Liberan a la hermana de Enner Valencia tras su...
# ...

# %%
# 2. Obtener el host

from urllib.parse import urlparse #Librería estándar de Python para parsear url

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                  body  \
# 0   \nLa intención de Lionel Messi era presentarse...
# 1   \n\nUn ejército de hombres y mujeres —la mayor...
# 2   \nAsí como "Capulina" o "El Chavo del Ocho", M...
# 3   \nElementos de la Unidad de Antisecuestro y Ex...
# 4   \nRelajada y en bikini aparece Aislinn Derbez ...
# ..                                                ...
# 40  Lorem ipsum dolor sit amet, consectetur adipis...
# 41  Nam lectus turpis, semper ac dui vel, ultricie...
# 42  Cras ut nisi enim. Integer porta congue vulput...
# 43  Cras ut nisi enim. Integer porta congue vulput...
# 44  Nam lectus turpis, semper ac dui vel, ultricie...
#
#                                                 title  \
# 0   Messi no se presentará a hacer exámenes con el...
# 1   Crece pepena durante la pandemia; van adultos ...
# 2   Las aventuras de Manuel "El Loco" Valdés divir...
# 3   Liberan a la hermana de Enner Valencia tras su...
# ...

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx    45
# Name: host, dtype: int64

# %% [markdown]
# # Missing data

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

missing_titles_mask
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# Name: title, Length: 45, dtype: bool

# %%
missing_titles_mask_2 = el_universal['title'].notna()

missing_titles_mask_2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# Name: title, Length: 45, dtype: bool

# %%
# Creacíón de df con los títulos faltantes

missing_titles = (el_universal[missing_titles_mask]['url']
                    .str.extract(r'(?P<missing_titles>[^/]+)$')
                    .applymap(lambda title: title.split('-'))
                    .applymap(lambda title_word_list: ' '.join(title_word_list))
                 )

missing_titles
# Out:
#    missing_titles
# 40      lorem uno
# 41      lorem dos
# 42     lorem tres
# 43     lorem tres
# 44      lorem dos

# %%
# Llenado del df con df de títulos faltantes

el_universal.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']

el_universal
# Out:
#                                                  body  \
# 0   \nLa intención de Lionel Messi era presentarse...
# 1   \n\nUn ejército de hombres y mujeres —la mayor...
# 2   \nAsí como "Capulina" o "El Chavo del Ocho", M...
# 3   \nElementos de la Unidad de Antisecuestro y Ex...
# 4   \nRelajada y en bikini aparece Aislinn Derbez ...
# ..                                                ...
# 40  Lorem ipsum dolor sit amet, consectetur adipis...
# 41  Nam lectus turpis, semper ac dui vel, ultricie...
# 42  Cras ut nisi enim. Integer porta congue vulput...
# 43  Cras ut nisi enim. Integer porta congue vulput...
# 44  Nam lectus turpis, semper ac dui vel, ultricie...
#
#                                                 title  \
# 0   Messi no se presentará a hacer exámenes con el...
# 1   Crece pepena durante la pandemia; van adultos ...
# 2   Las aventuras de Manuel "El Loco" Valdés divir...
# 3   Liberan a la hermana de Enner Valencia tras su...
# ...

# %% [markdown]
# ## Additional cleanup

# %%
# 4. Añadir uid a las filas

import hashlib

uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
        )

el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)

el_universal
# Out:
#                                                                                body  \
# uid
# c56be896eb40c6d02d9bad65d8d666db  \nLa intención de Lionel Messi era presentarse...
# 70d3eb8bdd44d6ee40d5ab984b283399  \n\nUn ejército de hombres y mujeres —la mayor...
# b55dddbb7f82e52caae88400c9798bee  \nAsí como "Capulina" o "El Chavo del Ocho", M...
# b961382465d8f77cd9c4be6b3e6149da  \nElementos de la Unidad de Antisecuestro y Ex...
# 7e0e0b9066b86313bf393c1b6450b890  \nRelajada y en bikini aparece Aislinn Derbez ...
# ...                                                                             ...
# a66608e1b3c49a2c217dc9574202f9e4  Lorem ipsum dolor sit amet, consectetur adipis...
# c0bc2d5c893a1cf7fbe4c260f4552c23  Nam lectus turpis, semper ac dui vel, ultricie...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# ...

# %%
stripped_body = (el_universal
                    .apply(lambda row: row['body'], axis=1)
                    .apply(lambda body: list(body))
                    .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                    .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uid
# c56be896eb40c6d02d9bad65d8d666db    La intención de Lionel Messi era presentarse e...
# 70d3eb8bdd44d6ee40d5ab984b283399    Un ejército de hombres y mujeres —la mayoría d...
# b55dddbb7f82e52caae88400c9798bee    Así como "Capulina" o "El Chavo del Ocho", Man...
# b961382465d8f77cd9c4be6b3e6149da    Elementos de la Unidad de Antisecuestro y Exto...
# 7e0e0b9066b86313bf393c1b6450b890    Relajada y en bikini aparece Aislinn Derbez en...
#                                                           ...
# a66608e1b3c49a2c217dc9574202f9e4    Lorem ipsum dolor sit amet, consectetur adipis...
# c0bc2d5c893a1cf7fbe4c260f4552c23    Nam lectus turpis, semper ac dui vel, ultricie...
# 05adc3c36d01145647a14cee97c9a83b    Cras ut nisi enim. Integer porta congue vulput...
# 05adc3c36d01145647a14cee97c9a83b    Cras ut nisi enim. Integer porta congue vulput...
# c0bc2d5c893a1cf7fbe4c260f4552c23    Nam lectus turpis, semper ac dui vel, ultricie...
# Length: 45, dtype: object

# %%
el_universal['body'] = stripped_body
el_universal
# Out:
#                                                                                body  \
# uid
# c56be896eb40c6d02d9bad65d8d666db  La intención de Lionel Messi era presentarse e...
# 70d3eb8bdd44d6ee40d5ab984b283399  Un ejército de hombres y mujeres —la mayoría d...
# b55dddbb7f82e52caae88400c9798bee  Así como "Capulina" o "El Chavo del Ocho", Man...
# b961382465d8f77cd9c4be6b3e6149da  Elementos de la Unidad de Antisecuestro y Exto...
# 7e0e0b9066b86313bf393c1b6450b890  Relajada y en bikini aparece Aislinn Derbez en...
# ...                                                                             ...
# a66608e1b3c49a2c217dc9574202f9e4  Lorem ipsum dolor sit amet, consectetur adipis...
# c0bc2d5c893a1cf7fbe4c260f4552c23  Nam lectus turpis, semper ac dui vel, ultricie...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# ...

# %% [markdown]
# ## Data enrichment

# %%
# 6 Tokenizar el título y el body

import nltk
from nltk.corpus import stopwords

# nltk.download('punkt') #Solo 1 vez descargar estos módulos de nltk
# nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
                .dropna()
                .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
                .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
                .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
                .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
                .apply(lambda valid_word_list: len(valid_word_list))
            )



el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')

el_universal
# Out:
#                                                                                body  \
# uid
# c56be896eb40c6d02d9bad65d8d666db  La intención de Lionel Messi era presentarse e...
# 70d3eb8bdd44d6ee40d5ab984b283399  Un ejército de hombres y mujeres —la mayoría d...
# b55dddbb7f82e52caae88400c9798bee  Así como "Capulina" o "El Chavo del Ocho", Man...
# b961382465d8f77cd9c4be6b3e6149da  Elementos de la Unidad de Antisecuestro y Exto...
# 7e0e0b9066b86313bf393c1b6450b890  Relajada y en bikini aparece Aislinn Derbez en...
# ...                                                                             ...
# a66608e1b3c49a2c217dc9574202f9e4  Lorem ipsum dolor sit amet, consectetur adipis...
# c0bc2d5c893a1cf7fbe4c260f4552c23  Nam lectus turpis, semper ac dui vel, ultricie...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# ...

# %%
el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')

el_universal
# Out:
#                                                                                body  \
# uid
# c56be896eb40c6d02d9bad65d8d666db  La intención de Lionel Messi era presentarse e...
# 70d3eb8bdd44d6ee40d5ab984b283399  Un ejército de hombres y mujeres —la mayoría d...
# b55dddbb7f82e52caae88400c9798bee  Así como "Capulina" o "El Chavo del Ocho", Man...
# b961382465d8f77cd9c4be6b3e6149da  Elementos de la Unidad de Antisecuestro y Exto...
# 7e0e0b9066b86313bf393c1b6450b890  Relajada y en bikini aparece Aislinn Derbez en...
# ...                                                                             ...
# a66608e1b3c49a2c217dc9574202f9e4  Lorem ipsum dolor sit amet, consectetur adipis...
# c0bc2d5c893a1cf7fbe4c260f4552c23  Nam lectus turpis, semper ac dui vel, ultricie...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# ...

# %% [markdown]
# ## Duplicate values

# %%
# 8. Eliminar duplicados

el_universal['title'].value_counts()
# Out:
# lorem dos                                                                  2
# lorem tres                                                                 2
# ¿Por qué Black Panther es considerado un hito en el cine?                  1
# Rayo mata a nueve niños mientras jugaban futbol en Uganda                  1
# Paty Navidad dice que la vacuna contra el coronavirus causará suicidios    1
#                                                                           ..
# Aislinn Derbez provoca envidias por su figura                              1
# El sufrimiento de las Chivas ante Pachuca en Guadalajara                   1
# Quien se quiera salir de la Conago, está en su derecho: Sheinbaum          1
# Raúl Gudiño se come gol en la Sub-20 y en redes lo atacan                  1
# Las aventuras de Manuel "El Loco" Valdés divirtieron en los cómics         1
# Name: title, Length: 43, dtype: int64

# %%
el_universal[el_universal['title'] == 'lorem tres']
# Out:
#                                                                                body  \
# uid
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
# 05adc3c36d01145647a14cee97c9a83b  Cras ut nisi enim. Integer porta congue vulput...
#
#                                        title  \
# uid
# 05adc3c36d01145647a14cee97c9a83b  lorem tres
# 05adc3c36d01145647a14cee97c9a83b  lorem tres
#
#                                                                               url  \
# uid
# 05adc3c36d01145647a14cee97c9a83b  https://www.eluniversal.com.mx/lorem/lorem-tres
# 05adc3c36d01145647a14cee97c9a83b  https://www.eluniversal.com.mx/lorem/lorem-tres
#
#                                  newspaper_uid                    host  \
# uid
# 05adc3c36d01145647a14cee97c9a83b  el_universal  www.eluniversal.com.mx
# 05adc3c36d01145647a14cee97c9a83b  el_universal  www.eluniversal.com.mx
#
#                                   n_tokens_title  n_tokens_body
# uid
# ...

# %%
el_universal.drop_duplicates(subset=['title'], keep='first', inplace=True)

el_universal['title'].value_counts()
# Out:
# Amber Riley dedica emotivo homenaje a Naya Rivera                                        1
# En 2020 se acabarán los “guardaditos” del país: Arturo Herrera                           1
# Paty Navidad dice que la vacuna contra el coronavirus causará suicidios                  1
# Declaran estado de emergencia en municipios de Jalisco por tormenta tropical “Hernán”    1
# Fallece iff Robinson, exestrella de la NBA                                               1
#                                                                                         ..
# El sufrimiento de las Chivas ante Pachuca en Guadalajara                                 1
# Quien se quiera salir de la Conago, está en su derecho: Sheinbaum                        1
# Raúl Gudiño se come gol en la Sub-20 y en redes lo atacan                                1
# Tortillería da esperanza para las clases                                                 1
# ...

# %% [markdown]
# ## Final table

# %%
# Tabla final

el_universal
# Out:
#                                                                                body  \
# uid
# c56be896eb40c6d02d9bad65d8d666db  La intención de Lionel Messi era presentarse e...
# 70d3eb8bdd44d6ee40d5ab984b283399  Un ejército de hombres y mujeres —la mayoría d...
# b55dddbb7f82e52caae88400c9798bee  Así como "Capulina" o "El Chavo del Ocho", Man...
# b961382465d8f77cd9c4be6b3e6149da  Elementos de la Unidad de Antisecuestro y Exto...
# 7e0e0b9066b86313bf393c1b6450b890  Relajada y en bikini aparece Aislinn Derbez en...
# ...                                                                             ...
# 1f048b851e3c50ad062097e9c5ca01c3  Sin duda alguna la muerte de Naya Rivera impac...
# c3ad8f892cd1864b2a61e07b0627ccd0  A los 53 años de edad, falleció el exjugador e...
# a66608e1b3c49a2c217dc9574202f9e4  Lorem ipsum dolor sit amet, consectetur adipis...
# c0bc2d5c893a1cf7fbe4c260f4552c23  Nam lectus turpis, semper ac dui vel, ultricie...
# ...

# %% [markdown]
# ## Drop missing values

# %%
el_universal.dropna()

el_universal
# Out:
#                                                                                body  \
# uid
# c56be896eb40c6d02d9bad65d8d666db  La intención de Lionel Messi era presentarse e...
# 70d3eb8bdd44d6ee40d5ab984b283399  Un ejército de hombres y mujeres —la mayoría d...
# b55dddbb7f82e52caae88400c9798bee  Así como "Capulina" o "El Chavo del Ocho", Man...
# b961382465d8f77cd9c4be6b3e6149da  Elementos de la Unidad de Antisecuestro y Exto...
# 7e0e0b9066b86313bf393c1b6450b890  Relajada y en bikini aparece Aislinn Derbez en...
# ...                                                                             ...
# 1f048b851e3c50ad062097e9c5ca01c3  Sin duda alguna la muerte de Naya Rivera impac...
# c3ad8f892cd1864b2a61e07b0627ccd0  A los 53 años de edad, falleció el exjugador e...
# a66608e1b3c49a2c217dc9574202f9e4  Lorem ipsum dolor sit amet, consectetur adipis...
# c0bc2d5c893a1cf7fbe4c260f4552c23  Nam lectus turpis, semper ac dui vel, ultricie...
# ...

# %% [markdown]
# ## Save data

# %%
# Saving data into new CSV

clean_filename = f'clean2_{filename}'
    
el_universal.to_csv(f'web_scrapper_curso_data_eng/{clean_filename}')

# %%
# Reading new data CSV

clean_el_universal = pd.read_csv(f'web_scrapper_curso_data_eng/{clean_filename}')

clean_el_universal
# Out:
#                                  uid  \
# 0   c56be896eb40c6d02d9bad65d8d666db
# 1   70d3eb8bdd44d6ee40d5ab984b283399
# 2   b55dddbb7f82e52caae88400c9798bee
# 3   b961382465d8f77cd9c4be6b3e6149da
# 4   7e0e0b9066b86313bf393c1b6450b890
# ..                               ...
# 38  1f048b851e3c50ad062097e9c5ca01c3
# 39  c3ad8f892cd1864b2a61e07b0627ccd0
# 40  a66608e1b3c49a2c217dc9574202f9e4
# 41  c0bc2d5c893a1cf7fbe4c260f4552c23
# 42  05adc3c36d01145647a14cee97c9a83b
#
#                                                  body  \
# 0   La intención de Lionel Messi era presentarse e...
# 1   Un ejército de hombres y mujeres —la mayoría d...
# 2   Así como "Capulina" o "El Chavo del Ocho", Man...
# 3   Elementos de la Unidad de Antisecuestro y Exto...
# 4   Relajada y en bikini aparece Aislinn Derbez en...
# ..                                                ...
# 38  Sin duda alguna la muerte de Naya Rivera impac...
# 39  A los 53 años de edad, falleció el exjugador e...
# ...

# %%
clean_data_from_recipe = pd.read_csv('web_scrapper_curso_data_eng/_clean_eluniversal_2020_08_29_articles2.csv')

clean_data_from_recipe
# Out:
#                                  uid  \
# 0   c56be896eb40c6d02d9bad65d8d666db
# 1   70d3eb8bdd44d6ee40d5ab984b283399
# 2   b55dddbb7f82e52caae88400c9798bee
# 3   b961382465d8f77cd9c4be6b3e6149da
# 4   7e0e0b9066b86313bf393c1b6450b890
# ..                               ...
# 38  1f048b851e3c50ad062097e9c5ca01c3
# 39  c3ad8f892cd1864b2a61e07b0627ccd0
# 40  a66608e1b3c49a2c217dc9574202f9e4
# 41  c0bc2d5c893a1cf7fbe4c260f4552c23
# 42  05adc3c36d01145647a14cee97c9a83b
#
#                                                  body  \
# 0   La intención de Lionel Messi era presentarse e...
# 1   Un ejército de hombres y mujeres —la mayoría d...
# 2   Así como "Capulina" o "El Chavo del Ocho", Man...
# 3   Elementos de la Unidad de Antisecuestro y Exto...
# 4   Relajada y en bikini aparece Aislinn Derbez en...
# ..                                                ...
# 38  Sin duda alguna la muerte de Naya Rivera impac...
# 39  A los 53 años de edad, falleció el exjugador e...
# ...

# %% [markdown]
# ## Test for scraping https://lajornada.com.mx/

# %%
import requests

response = requests.get('https://www.jornada.com.mx/')

# %%
import bs4

soup = bs4.BeautifulSoup(response.text, 'html.parser')

# print(soup.title.text)
# print(soup.select('meta[name=description]')) #Selector etiquetas
# print(soup.select('meta[name=description]')[0]['content'])

news_links = soup.select('.ljn-titles a')
# print(news_links)
news = [news['href'] for news in news_links]

for new in news:
    print(new)
# Out:
# https://www.jornada.com.mx/ultimas/politica/2020/09/06/por-contingencia-cancelan-simulacro-de-sismo-del-19-de-septiembre-1315.html
# /ultimas/especiales/migrantes-en-mexico

# %%
news_body = soup.select('#content_nitf')
print(news_body)
# Out:
# []

# %%
lajornada = pd.read_csv('web_scrapper_curso_data_eng/lajornada_2020_09_06_articles0.csv')

lajornada
# Out:
#                                                  body  \
# 0   Kagoshima, Japón. Un potente tifón golpea desd...
# 1   Londres. El fundador de Wikileaks, Julian Assa...
# 2   Washington. Jacob Blake, el hombre negro que r...
# 3   Zacatecas. Antonio Guzmán Fernández, rector de...
# 4    Ciudad de México. Para diversificar las alter...
# ..                                                ...
# 30  Ciudad de México. La recuperación del sector t...
# 31  Monza, Italia. El francés Pierre Gasly (Alpha ...
# 32  Ciudad de México. El rediseño de espacio aéreo...
# 33  Ciudad de México. La Coordinación Nacional de ...
# 34  Ciudad de México. La jefa de Gobierno de la Ci...
#
#                                                 title  \
# 0   El tifón Haishen golpea Japón con lluvias torr...
# 1      Assange impugnará intento de extradición de EU
# 2   Jacob Blake, afroamericano baleado por policía...
# 3   Debido al Covid-19, el rector de la UAZ seguir...
# ...

# %%
clean_lajornada = pd.read_csv('web_scrapper_curso_data_eng/_clean_lajornada_2020_09_06_articles0.csv')

clean_lajornada
# Out:
#                                  uid  \
# 0   0106c58deeae54cbb03b3920331382a2
# 1   a1ed3ccf83799ae519b04425d8d6aa9e
# 2   85ff45fd7bfc888792f72b1a9aa5d7a6
# 3   9a8363c48acf9c74fc6c97dcf8a21e47
# 4   15b78fbf6eebdc1d19a3fbb5597125a7
# ..                               ...
# 30  0bdab93d6b429f460299fd86dc34cbe1
# 31  3f7d7fbe9ba950c6df863afe383066dd
# 32  62e5f6d2f663b1463cb5271ff52aac54
# 33  aa90050295bfd7a96027e1cd47ee705a
# 34  2a07dc0363798f41a9757651fff21617
#
#                                                  body  \
# 0   Kagoshima, Japón. Un potente tifón golpea desd...
# 1   Londres. El fundador de Wikileaks, Julian Assa...
# 2   Washington. Jacob Blake, el hombre negro que r...
# 3   Zacatecas. Antonio Guzmán Fernández, rector de...
# 4    Ciudad de México. Para diversificar las alter...
# ..                                                ...
# 30  Ciudad de México. La recuperación del sector t...
# 31  Monza, Italia. El francés Pierre Gasly (Alpha ...
# ...

# %% [markdown]
# ## Descriptive analysis

# %%
import pandas as pd

clean_eluniversal = pd.read_csv('web_scrapper_curso_data_eng/_clean_eluniversal_2020_08_29_articles2.csv')
clean_lajornada = pd.read_csv('web_scrapper_curso_data_eng/_clean_lajornada_2020_09_06_articles0.csv')

# %%
clean_el_universal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       43.000000      43.000000
# mean         6.209302     239.372093
# std          2.110723     314.978081
# min          1.000000      72.000000
# 25%          5.000000     106.500000
# 50%          6.000000     157.000000
# 75%          7.500000     224.000000
# max         11.000000    2051.000000

# %%
clean_lajornada.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       35.000000      35.000000
# mean         5.914286     280.085714
# std          1.172514     264.365208
# min          2.000000      80.000000
# 25%          5.000000     150.500000
# 50%          6.000000     206.000000
# 75%          7.000000     284.000000
# max          8.000000    1502.000000

# %%
clean_lajornada.loc[clean_lajornada['n_tokens_title'] == 0]
# Out:
# Empty DataFrame
# Columns: [uid, body, title, url, newspaper_uid, host, n_tokens_title, n_tokens_body]
# Index: []

# %%
# %matplotlib inline

# %%
clean_lajornada['n_tokens_title'].plot(style='k.')
clean_el_universal['n_tokens_title'].plot(style='r.')
# Out:
# <AxesSubplot:>

# %%
clean_lajornada['n_tokens_body'].plot(style='k.')
clean_el_universal['n_tokens_body'].plot(style='r.')
# Out:
# <AxesSubplot:>

# %%
all_newspapers = pd.concat([clean_el_universal, clean_lajornada])

grouped = all_newspapers.groupby('newspaper_uid')

grouped.hist()
# Out:
# newspaper_uid
# el_universal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# lajornada       [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min', 'mean', 'max'])
# Out:
#                min        mean   max
# newspaper_uid
# el_universal    72  239.372093  2051
# lajornada       80  280.085714  1502

# %%
grouped.plot()
# Out:
# newspaper_uid
# el_universal    AxesSubplot(0.125,0.125;0.775x0.755)
# lajornada       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
